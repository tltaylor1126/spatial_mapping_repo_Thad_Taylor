# %% [markdown]
# # Mini Quiz - Working with Data Advanced

# %% [markdown]
# ## 1. Create a Pandas Series and DataFrame.

# %%
import pandas as pd
s = pd.Series([10, 20, 30], name="score")
df = pd.DataFrame({"name": ["Ada", "Grace", "Alan"], "score": s})
display(s)
display(df)

# %% [markdown]
# ## 2. Filter and sort data.

# %%
import pandas as pd
pokemon = pd.read_csv("data/pokemon.csv")
display(pokemon.head())
print(pokemon.shape)

# %% [markdown]
# ## 3. Report missing values.

# %%
import pandas as pd
survey = pd.read_csv("data/survey.csv")
print(survey.isnull().sum())
