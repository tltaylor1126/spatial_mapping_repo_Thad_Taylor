# %% [markdown]
# # 📝 Foundations Quiz
#
# This quiz covers material from the **Foundations** notebooks (01–08).
# Answer each question in the provided cell. Some questions require code, others are written answers.

# %% [markdown]
# ## Q1. Magics
# What does `%whos` display? Write your answer below.

# %% [markdown]
# *Answer:* `%whos` displays the variables currently defined in the notebook session, including their names, types, values, and summary information such as size when available.

# %% [markdown]
# ## Q2. Markdown
# Create a Markdown cell with a heading `## My Hobbies` and a bullet list of at least 3 hobbies.

# %% [markdown]
# ## My Hobbies
#
# - Mapping and geography projects
# - Programming in Python
# - Playing strategy games
# - Reading about technology

# %% [markdown]
# ## Q3. Files and Paths
# Use `%pwd` to print your current working directory.

# %%
# %pwd

# %% [markdown]
# ## Q4. File I/O
# Write Python code that saves `Hello World` to a file called `hello.txt`, then reads it back and prints the contents.

# %%
from pathlib import Path
path = Path("hello.txt")
path.write_text("Hello World", encoding="utf-8")
print(path.read_text(encoding="utf-8"))

# %% [markdown]
# ## Q5. Data I/O
# Load the file `students.csv` (or create a small CSV yourself) with Pandas and show the first 5 rows.

# %%
from pathlib import Path
import pandas as pd
csv_path = Path("students.csv")
if not csv_path.exists():
    csv_path.write_text("name,grade\nAda,98\nGrace,95\nAlan,91\n", encoding="utf-8")
students = pd.read_csv(csv_path)
students.head()

# %% [markdown]
# ## Q6. Plotting
# Create a line plot of $y = x^2$ for $x$ values from 0 to 10.

# %%
import matplotlib.pyplot as plt
x = list(range(11))
y = [value ** 2 for value in x]
plt.plot(x, y, marker="o")
plt.xlabel("x")
plt.ylabel("x squared")
plt.title("y = x^2")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## Q7. Shortcuts
# In Command mode, what keyboard shortcut deletes a cell?

# %% [markdown]
# *Answer:* Press `D` twice in command mode to delete the selected cell.

# %% [markdown]
# ## Q8. Help and Docs
# Use `?` to display the docstring for `len`. Show the result.

# %%
# ?len

# %% [markdown]
# ## Q9. Timing
# Compare the runtime of squaring numbers using a Python loop vs. NumPy. Use `%timeit` for each.

# %%
import numpy as np
numbers = list(range(10_000))
arr = np.arange(10_000)
# %timeit [n ** 2 for n in numbers]
# %timeit arr ** 2

# %% [markdown]
# ## Q10. Reflection
# Why is it useful to mix Markdown and code in Jupyter notebooks? Write 2–3 sentences.

# %% [markdown]
# *Answer:* Markdown explains the purpose, assumptions, and results around the code, while code cells perform the actual computation. Mixing them makes a notebook readable as both a working program and a report someone else can follow later.
