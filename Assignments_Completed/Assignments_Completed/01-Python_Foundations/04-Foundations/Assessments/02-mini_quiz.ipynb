# %% [markdown]
# # Mini Quiz - Foundations

# %% [markdown]
# ## 1. What does `%pwd` show in a notebook?

# %%
# Answer 1
# %pwd prints the current working directory used by the notebook kernel.
# %pwd

# %% [markdown]
# ## 2. What is the purpose of Markdown cells?

# %%
# Answer 2
print("Markdown cells are for formatted notes, headings, lists, links, and explanations.")

# %% [markdown]
# ## 3. Write and read a small text file.

# %%
from pathlib import Path
path = Path("mini_quiz_note.txt")
path.write_text("Foundations quiz complete", encoding="utf-8")
print(path.read_text(encoding="utf-8"))
