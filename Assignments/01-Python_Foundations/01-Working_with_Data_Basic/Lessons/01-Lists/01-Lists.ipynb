# %% [markdown]
# # 📘 01 - Python Lists
#
# Explore how to use lists to store and manipulate data.

# %% [markdown]
# ## ✅ Learning Goals
# - Create and modify Python lists
# - Access elements using indexing
# - Use list methods like `append()`, `remove()`, and `sort()`

# %%
# 🔧 Create a List
my_list = [10, 20, 30, 40, 50]
print(my_list)
# Out:
# [10, 20, 30, 40, 50]

# %%
# 🎯 Access Elements
print('First item:', my_list[0])
print('Last item:', my_list[-1])
# Out:
# First item: 10
# Last item: 50

# %%
# ➕ Modify List
my_list.append(60)
my_list.remove(30)
print(my_list)
# Out:
# [10, 20, 40, 50, 60]

# %%
# 🔁 Loop Through List
for item in my_list:
    print(item)
# Out:
# 10
# 20
# 40
# 50
# 60

# %% [markdown]
# ## ✏️ Your Turn
# Create your own list of 5 favorite movies and sort them alphabetically.

# %%
movie_list = ["The Iron Giant", "No Country for Old Men", "Alien", "Iron Man", "Fantastic Four: First Steps"]
print('List of Movies: ', movie_list)
sorted_list = sorted(movie_list)
print('Sorted List: ', sorted_list)
# Out:
# List of Movies:  ['The Iron Giant', 'No Country for Old Men', 'Alien', 'Iron Man', 'Fantastic Four: First Steps']
# Sorted List:  ['Alien', 'Fantastic Four: First Steps', 'Iron Man', 'No Country for Old Men', 'The Iron Giant']
