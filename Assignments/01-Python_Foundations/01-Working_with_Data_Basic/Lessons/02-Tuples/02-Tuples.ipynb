# %% [markdown]
# # 📘 02 - Python Tuples
#
# Learn what tuples are and how to use them.

# %% [markdown]
# ## ✅ Learning Goals
# - Create and access tuples
# - Understand immutability
# - Use tuple unpacking

# %%
# 🔧 Create a Tuple
coords = (5, 10)
print(coords)
# Out:
# (5, 10)

# %%
# 🔍 Indexing
print('X:', coords[0])
print('Y:', coords[1])
# Out:
# X: 5
# Y: 10

# %%
# 🔁 Tuple Unpacking
x, y = coords
print('x + y =', x + y)
# Out:
# x + y = 15

# %% [markdown]
# ## 🚫 Tuples are immutable
# Try uncommenting the line below to see what happens:
# ```python
# # coords[0] = 100
# ```

# %%
coords[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 coords[0] = 100
#
# TypeError: 'int' object does not support item assignment

# %% [markdown]
# ## ✏️ Your Turn
# Create a tuple to store your birthday as `(month, day, year)`.

# %%
bday = (11, 26, 2003)
print('My Birthday is:', bday[0], '/', bday[1], '/', bday[2])
# Out:
# My Birthday is: 11 / 26 / 2003
